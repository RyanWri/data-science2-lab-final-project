# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
from task_9.task_9 import EDA, read_excel_sheet

# %%
# Move two directories up
data_dir = os.path.abspath(os.path.join(os.getcwd(), "..", "data"))

# Construct the full path to the file
file_absolute_path = os.path.join(data_dir, "rehospitalization.xlsx")
df = read_excel_sheet(file_absolute_path, "hospitalization1")

# %% [markdown]
# # Hospitalization 1 EDA

# %%
hospitilazation1 = EDA(df)

# %%
hospitilazation1.stats()
# Out:
#    Patient  unitName1  ...  אבחנות בקבלה            אבחנות בשחרור
# 0    62051          1  ...         42731                    42731
# 1   951769          2  ...        Z3601                    Z3601
# 2   863707          2  ...          7895                     7895
# 3   884200          3  ...         78609            4919 , 78609
# 4   936226          4  ...         78609   78609 , 81203 , 83100
#
# [5 rows x 12 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7033 entries, 0 to 7032
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Patient                   7033 non-null   int64
#  1   unitName1                 7033 non-null   int64
#  2   Admission_Medical_Record  7033 non-null   int64
#  3   Admission_Entry_Date      7033 non-null   datetime64[ns]
#  4   Release_Date              7033 non-null   datetime64[ns]
#  5   סוג קבלה                  6969 non-null   object
#  6   מהיכן המטופל הגיע         7033 non-null   object
#  7   Release_Type              7033 non-null   object
#  8   רופא משחרר-קוד            6919 non-null   float64
#  9   ימי אשפוז                 7033 non-null   int64
#  10  אבחנות בקבלה              6572 non-null   object
#  11  אבחנות בשחרור             7004 non-null   object
# dtypes: datetime64[ns](2), float64(1), int64(4), object(5)
# memory usage: 659.5+ KB
# None
#             Patient    unitName1  ...  רופא משחרר-קוד    ימי אשפוז
# count  7.033000e+03  7033.000000  ...     6919.000000  7033.000000
# mean   3.321263e+05     2.940708  ...    10169.482295     3.198777
# std    3.178396e+05     1.411208  ...     2925.033899     3.710708
# min    3.100000e+01     1.000000  ...     1052.000000    -1.000000
# 25%    7.352200e+04     2.000000  ...    10112.000000     1.000000
# 50%    2.059390e+05     3.000000  ...    11119.000000     2.000000
# 75%    5.566750e+05     4.000000  ...    11833.000000     4.000000
# max    1.171452e+06     5.000000  ...    12916.000000    50.000000
#
# [8 rows x 5 columns]
# Patient                       0
# unitName1                     0
# Admission_Medical_Record      0
# Admission_Entry_Date          0
# Release_Date                  0
# סוג קבלה                     64
# מהיכן המטופל הגיע             0
# Release_Type                  0
# רופא משחרר-קוד              114
# ימי אשפוז                     0
# אבחנות בקבלה                461
# אבחנות בשחרור                29
# dtype: int64

# %%
hospitilazation1.histogram()
# Out:
# [[<Axes: title={'center': 'Patient'}>
#   <Axes: title={'center': 'unitName1'}>
#   <Axes: title={'center': 'Admission_Medical_Record'}>]
#  [<Axes: title={'center': 'Admission_Entry_Date'}>
#   <Axes: title={'center': 'Release_Date'}>
#   <Axes: title={'center': 'רופא משחרר-קוד'}>]
#  [<Axes: title={'center': 'ימי אשפוז'}> <Axes: > <Axes: >]]
# 31075     53
# 354573    23
# 65151     14
# 3523      13
# 34605     13
#           ..
# 590181     1
# 790490     1
# 6181       1
# 801748     1
# 431801     1
# Name: Patient, Length: 4515, dtype: int64
# 1    1582
# 4    1582
# 3    1392
# 2    1263
# 5    1214
# Name: unitName1, dtype: int64
# 5207766    1
# 4638165    1
# 4684750    1
# 6659199    1
# 6194540    1
#           ..
# 7240838    1
# 6422712    1
# 7232954    1
# 6810555    1
# 7229378    1
# Name: Admission_Medical_Record, Length: 7033, dtype: int64
# 2021-09-04 22:21:04.440    1
# 2021-01-10 05:03:11.557    1
# 2021-01-29 21:15:59.523    1
# 2023-04-01 01:39:41.437    1
# 2022-09-24 02:36:33.567    1
#                           ..
# 2023-11-26 15:30:32.170    1
# 2022-12-29 22:00:43.417    1
# 2023-11-22 18:41:23.047    1
# 2023-06-05 14:00:02.710    1
# 2023-11-21 16:22:11.033    1
# Name: Admission_Entry_Date, Length: 7033, dtype: int64
# 2023-07-06 15:00:00    4
# 2020-06-29 16:00:00    3
# 2023-11-29 16:00:00    3
# 2021-05-23 16:00:00    3
# 2022-12-15 17:44:00    2
#                       ..
# 2021-05-09 21:04:00    1
# 2020-11-15 16:40:00    1
# 2020-06-27 16:34:00    1
# 2020-09-21 16:18:00    1
# 2023-11-22 14:09:00    1
# Name: Release_Date, Length: 6926, dtype: int64
# דחוף         6284
# מוזמן         670
# אשפוז יום      15
# Name: סוג קבלה, dtype: int64
# מביתו             5604
# ממוסד              963
# אחר                375
# ממרפאה              59
# מבית חולים אחר      32
# Name: מהיכן המטופל הגיע, dtype: int64
# שוחרר לביתו    6641
# שוחרר למוסד     392
# Name: Release_Type, dtype: int64
# 6888.0     231
# 10313.0    153
# 11460.0    143
# 10760.0    140
# 10676.0    136
#           ...
# 7359.0       1
# 11884.0      1
# 6884.0       1
# 11844.0      1
# 2213.0       1
# Name: רופא משחרר-קוד, Length: 214, dtype: int64
#  1     2026
#  2     1415
#  3      925
#  0      610
#  4      588
#  5      362
#  6      278
#  7      240
#  8      130
#  9       93
#  10      56
#  12      52
#  11      49
#  13      40
#  14      28
#  15      27
#  17      16
#  16      15
#  19      15
#  18      13
#  21      10
#  20       6
#  24       4
#  26       4
#  27       3
#  22       3
# -1        3
#  28       3
#  35       2
#  29       2
#  31       2
#  23       2
#  25       2
#  45       1
#  34       1
#  41       1
#  43       1
#  32       1
#  50       1
#  33       1
#  49       1
#  37       1
# Name: ימי אשפוז, dtype: int64
# 78609                                381
# 7865                                 362
# 78060                                304
#  O8889                               211
# 2859                                 187
#                                     ...
#  Z9392                                 1
#  78609 , 78701                         1
#  2859 , 401 , 4280 , 5859 , 7823       1
#  079.84 , 78906                        1
#  78609 , 790.92 , V73.70               1
# Name: אבחנות בקבלה, Length: 1664, dtype: int64
# 7865                                      275
# 78609                                     240
#  O8889                                    203
# 78060                                     194
# 2859                                      148
#                                          ...
#  4019 , 5184                                1
#  7807 , O8889 , Z0066                       1
#  2767 , 41071 , 5849                        1
#  25000 , 7802 , 78321                       1
#  2767 , 514 , 78609 , 790.92 , V73.70       1
# Name: אבחנות בשחרור, Length: 2831, dtype: int64

# %%
hospitilazation1.correlation()
# Out:
# c:\Afeka\data-science2-lab-final-project\src\team_1\task_9\task_9.py:54: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(self.df.corr())
# c:\Afeka\data-science2-lab-final-project\src\team_1\task_9\task_9.py:57: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(self.df.corr(), annot=True, cmap="coolwarm", fmt=".2f")
#                            Patient  unitName1  ...  רופא משחרר-קוד  ימי אשפוז
# Patient                   1.000000   0.000879  ...       -0.034714   0.033358
# unitName1                 0.000879   1.000000  ...        0.191134   0.016372
# Admission_Medical_Record  0.135346   0.025465  ...       -0.142217  -0.055634
# רופא משחרר-קוד           -0.034714   0.191134  ...        1.000000   0.017985
# ימי אשפוז                 0.033358   0.016372  ...        0.017985   1.000000
#
# [5 rows x 5 columns]
